# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, plot_confusion_matrix, plot_roc_curve, classification_report
from sklearn.preprocessing import StandardScaler
import warnings 

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Dataset

# %%
from sklearn.datasets import fetch_openml
MNIST = fetch_openml('mnist_784')
feature = MNIST.data
label = MNIST.target

# %% [markdown]
# ## Displaying images

# %%
# checking whether data is properly loaded or not
i = 1
for image in feature[0:16]:
    image = image.reshape(28,28)
    plt.subplot(4,4,i)
    plt.imshow(image)
    i+=1

# %% [markdown]
# ## Count plot of data

# %%
# checking whether data is balanced or not
sns.countplot(label)
plt.show()

# %% [markdown]
# The data seems to be balanced

# %% [markdown]
# ## Splitting dataset into train and test

# %%
from sklearn.model_selection import train_test_split

# splitting data into 80:20
x_train, x_test, y_train, y_test = train_test_split(feature, label, test_size = 0.2, random_state = 42)

# %% [markdown]
# ## Training a random_forest classifier

# %%
clf = RandomForestClassifier(n_estimators=200, n_jobs=-1)

clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1)

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# ### Accuracy

# %%
# evaluating training performance
y_pred_train = clf.predict(x_train)
print('Train accuracy:', accuracy_score(y_train, y_pred_train))

# evaluating test performance
y_pred = clf.predict(x_test)
print('Test accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Train accuracy: 1.0
# Test accuracy: 0.9678571428571429

# %% [markdown]
# ### Confusion Matrix

# %%
fig, ax = plt.subplots(figsize=(10, 10))
plot_confusion_matrix(clf, x_test, y_test, ax=ax, cmap='Blues')

# %% [markdown]
# ### Classification Report

# %%
print('Classification report\n',classification_report(y_test, y_pred))
# Out:
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1343
#            1       0.98      0.99      0.98      1600
#            2       0.95      0.97      0.96      1380
#            3       0.96      0.95      0.95      1433
#            4       0.97      0.97      0.97      1295
#            5       0.97      0.96      0.97      1273
#            6       0.98      0.99      0.98      1396
#            7       0.97      0.97      0.97      1503
#            8       0.96      0.96      0.96      1357
#            9       0.95      0.95      0.95      1420
#
#     accuracy                           0.97     14000
#    macro avg       0.97      0.97      0.97     14000
# weighted avg       0.97      0.97      0.97     14000

# %% [markdown]
# **Model reached test accuracy 97%**

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
from scipy.linalg import eigh

# %% [markdown]
# ### 2D visualization of dataset on two principal component axes

# %%
# scaling the data
scaler = StandardScaler()
x_train_std = scaler.fit_transform(x_train)

# creating covariance matrix for extracting eigenvalues and eigenvectors
cov_matrix = np.matmul(x_train_std.T, x_train_std)
e_values, e_vectors = eigh(cov_matrix, eigvals=(782,783))
pcs = np.matmul(e_vectors.T, x_train_std.T)
pca_df = pd.DataFrame(pcs.T, columns=('pc1', 'pc2'))
pca_df['label'] = y_train
sns.FacetGrid(pca_df, hue='label', size=10).map(plt.scatter, 'pc1', 'pc2').add_legend()

# %% [markdown]
# ## Cumulative variance vs dimensionality

# %%
pca = PCA(n_components = 784)
pca_data = pca.fit_transform(x_train)
variance_explained = pca.explained_variance_/np.sum(pca.explained_variance_)
cum_variance_explained = np.cumsum(variance_explained)
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
plt.plot(cum_variance_explained)
plt.xlabel('n_components')
plt.ylabel('cum_variance_explained')
plt.show()

# %% [markdown]
# **The above plot explains that out of 784 dimensions only 100 dimensions are enough to explain more than 90% of the variance**

# %%
print("Cumulative variance explained with 40 dimensions :", cum_variance_explained[39])
# Out:
# Cumulative variance explained with 40 dimensions : 0.7871704370057738

# %% [markdown]
# ## Reducing the dimension from 784 to 40

# %%
n = 40
pca = PCA(n_components=n)
pca.fit(x_train)
x_train_pca = pca.transform(x_train)
x_test_pca = pca.transform(x_test)

# %% [markdown]
# ## Training a random_forest classifier on reduced dataset

# %%
clf = RandomForestClassifier(n_estimators=200, n_jobs=-1)
clf.fit(x_train_pca, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Accuracy

# %%
# evaluating training performance
y_pred_train = clf.predict(x_train_pca)
print('Train accuracy:', accuracy_score(y_train, y_pred_train))

# evaluating test performance
y_pred = clf.predict(x_test_pca)
print('Test accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Train accuracy: 1.0
# Test accuracy: 0.955

# %% [markdown]
# ### Confusion Matrix

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.set_style('white')
plot_confusion_matrix(clf, x_test_pca, y_test, ax=ax, cmap='Blues')

# %% [markdown]
# ### Classicication Report

# %%
print('Classification report\n',classification_report(y_test, y_pred))
# Out:
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1343
#            1       0.98      0.98      0.98      1600
#            2       0.95      0.95      0.95      1380
#            3       0.93      0.94      0.93      1433
#            4       0.94      0.96      0.95      1295
#            5       0.95      0.95      0.95      1273
#            6       0.97      0.98      0.97      1396
#            7       0.96      0.96      0.96      1503
#            8       0.94      0.91      0.93      1357
#            9       0.94      0.93      0.94      1420
#
#     accuracy                           0.95     14000
#    macro avg       0.95      0.95      0.95     14000
# weighted avg       0.95      0.95      0.95     14000

# %% [markdown]
# ______________________________________________________
